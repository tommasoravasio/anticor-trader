# %%
import pandas as pd
import numpy as np
import wrds
from datetime import datetime
import matplotlib.pyplot as plt

# =============================================================================
# ÉTAPE 1: CONNEXION WRDS ET PARAMÈTRES
# =============================================================================
print("🚀 Étape 1: Connexion à WRDS et définition des paramètres...")
db = wrds.Connection()
end_date = '2025-01-30'
trading_days = 1276
start_date_approx = (pd.to_datetime(end_date) - pd.to_timedelta(trading_days * 1.8, unit='d')).strftime('%Y-%m-%d')
num_stocks = 25
print("✅ Connexion et paramètres définis.")

# =============================================================================
# ÉTAPE 2: SÉLECTION DE L'UNIVERS (TOP 25 S&P 500)
# =============================================================================
print("\n🚀 Étape 2: Sélection de l'univers des 25 plus grosses capitalisations...")
query_last_date = f"SELECT max(date) as last_date FROM crsp.dsf WHERE date <= '{end_date}'"
last_date_df = db.raw_sql(query_last_date, date_cols=['last_date'])
last_trading_day_str = last_date_df['last_date'][0].strftime('%Y-%m-%d')
end_date = last_trading_day_str
query_universe = f"""
    WITH sp500_constituents AS (SELECT permno FROM crsp.msp500list WHERE '{end_date}' BETWEEN start AND ending),
    market_cap AS (
        SELECT a.permno, ABS(a.prc * a.shrout) as mktcap
        FROM crsp.dsf AS a JOIN sp500_constituents AS b ON a.permno = b.permno
        WHERE a.date = '{end_date}' AND a.prc IS NOT NULL AND a.shrout IS NOT NULL
    )
    SELECT permno FROM market_cap ORDER BY mktcap DESC LIMIT {num_stocks}
"""
top_25_permno = db.raw_sql(query_universe)['permno'].tolist()
permno_tuple = tuple(top_25_permno)
print(f"✅ Univers de {len(top_25_permno)} actions identifié.")

# =============================================================================
# ÉTAPE 3: TÉLÉCHARGEMENT DES DONNÉES HISTORIQUES
# =============================================================================
print("\n🚀 Étape 3: Téléchargement des données (avec COMNAM et TICKER)...")
query_data = f"""
    SELECT a.permno, a.date, a.ret, b.dlret, c.comnam, c.ticker
    FROM crsp.dsf AS a
    LEFT JOIN crsp.dsedelist AS b ON a.permno = b.permno AND a.date = b.dlstdt
    LEFT JOIN crsp.msenames AS c ON a.permno = c.permno AND a.date BETWEEN c.namedt AND c.nameendt
    WHERE a.permno IN {permno_tuple} AND a.date BETWEEN '{start_date_approx}' AND '{end_date}'
"""
daily_data = db.raw_sql(query_data, date_cols=['date'])
daily_data['comnam'] = daily_data.groupby('permno')['comnam'].transform(lambda x: x.ffill().bfill())
daily_data['ticker'] = daily_data.groupby('permno')['ticker'].transform(lambda x: x.ffill().bfill())
permno_to_name = daily_data.drop_duplicates('permno').set_index('permno')['comnam'].to_dict()
permno_to_ticker = daily_data.drop_duplicates('permno').set_index('permno')['ticker'].to_dict()
all_dates = sorted(daily_data['date'].unique())
final_dates = all_dates[-trading_days:]
daily_data = daily_data[daily_data['date'].isin(final_dates)]
print("✅ Téléchargement terminé.")
db.close()
print("🔒 Connexion WRDS fermée.")

# =============================================================================
# ÉTAPE 4: NETTOYAGE ET CRÉATION DE LA MATRICE
# =============================================================================
print("\n🚀 Étape 4: Nettoyage et construction de la matrice finale...")
daily_data['ret'] = pd.to_numeric(daily_data['ret'], errors='coerce').fillna(0)
daily_data['dlret'] = pd.to_numeric(daily_data['dlret'], errors='coerce').fillna(0)
daily_data['effective_ret'] = (1 + daily_data['ret']) * (1 + daily_data['dlret']) - 1
daily_data['price_relative'] = 1 + daily_data['effective_ret']
final_matrix_relatives = daily_data.pivot(index='date', columns='permno', values='price_relative')
final_matrix_relatives.ffill(inplace=True)
final_matrix_relatives.fillna(1.0, inplace=True)
print("✅ Matrice des relatifs de prix construite !")

# ### PRINT DE DEBUG : AFFICHER L'UNIVERS FINAL ###
print("\n--- Actions dans l'univers du backtest ---")
# On utilise le dictionnaire pour afficher les tickers au lieu des PERMNO
tickers_in_matrix = [permno_to_ticker.get(p, str(p)) for p in final_matrix_relatives.columns]
print(tickers_in_matrix)
print(f"Shape de la matrice : {final_matrix_relatives.shape}")
print("------------------------------------------\n")

# =============================================================================
# FONCTION DE STRATÉGIE ANTICOR(w) - AVEC PRINTS DE DEBUG
# =============================================================================
# =============================================================================
# FONCTION DE STRATÉGIE ANTICOR(w) - VERSION CORRIGÉE AVEC PRINTS DE SYNTHÈSE
# =============================================================================

def run_anticor_strategy(price_relatives: pd.DataFrame, w: int, permno_to_ticker: dict, debug_days: int = 3):
    """
    Exécute la stratégie ANTICOR(w) avec des prints de debug synthétiques.
    Cette version corrige l'erreur de calcul de la corrélation.
    """
    m = price_relatives.shape[1]
    n = len(price_relatives)
    asset_permnos = price_relatives.columns
    
    log_relatives = np.log(price_relatives)
    
    weights_history, daily_returns_history, dates_history = [], [], []
    
    # Le portefeuille est initialisé de manière uniforme pour le PREMIER jour de trading (t=2w)
    b_t = pd.Series(1/m, index=asset_permnos)
    
    # La boucle commence à 2*w, qui est le premier jour où l'on peut calculer un rendement.
    for t in range(2 * w, n):
        is_debug_day = t < (2 * w + debug_days)

        if is_debug_day:
            print(f"\n==================== JOUR DE TRADING: {price_relatives.index[t].date()} (t={t}) ====================")
            print(f"Portefeuille utilisé pour AUJOURD'HUI (décidé hier, b_t):\n{b_t.rename(permno_to_ticker).sort_values(ascending=False).head().to_string(float_format='{:.2%}'.format)}")
            
        # 1. Calcul du rendement du jour t en utilisant les poids b_t décidés la veille
        daily_return = (b_t * price_relatives.iloc[t]).sum() - 1
        dates_history.append(price_relatives.index[t])
        daily_returns_history.append(daily_return)
        weights_history.append(b_t.to_dict())

        # 2. Préparation du portefeuille pour le JOUR SUIVANT (t+1) en utilisant les données jusqu'à AUJOURD'HUI (t)
        
        # Le portefeuille est d'abord mis à jour avec les rendements du jour t
        b_t_rebalanced = (b_t * price_relatives.iloc[t]) / (b_t * price_relatives.iloc[t]).sum()
        
        lx1 = log_relatives.iloc[t - 2*w + 1 : t - w + 1]
        lx2 = log_relatives.iloc[t - w + 1 : t + 1]
        mu2 = lx2.mean()
        
        # --- CORRECTION : Retour à la boucle pour le calcul correct de M_cor ---
        m_cor = pd.DataFrame(0.0, index=asset_permnos, columns=asset_permnos)
        for i in asset_permnos:
            for j in asset_permnos:
                lx1_i_std = lx1[i].std()
                lx2_j_std = lx2[j].std()
                if lx1_i_std > 1e-8 and lx2_j_std > 1e-8:
                    m_cor.loc[i, j] = np.corrcoef(lx1[i], lx2[j])[0, 1]
        
        claims = pd.DataFrame(0.0, index=asset_permnos, columns=asset_permnos)
        for i in asset_permnos:
            for j in asset_permnos:
                if i != j and mu2[i] > mu2[j] and m_cor.loc[i, j] > 0:
                    claim_val = m_cor.loc[i, j]
                    if m_cor.loc[i, i] < 0: claim_val -= m_cor.loc[i, i]
                    if m_cor.loc[j, j] < 0: claim_val -= m_cor.loc[j, j]
                    claims.loc[i, j] = claim_val
        
        total_claims_out = claims.sum(axis=1)
        b_tplus1 = b_t_rebalanced.copy()
        
        for i in asset_permnos:
            if total_claims_out[i] > 0:
                for j in asset_permnos:
                    if i != j:
                        transfer_ij = b_t_rebalanced[i] * (claims.loc[i, j] / total_claims_out[i])
                        b_tplus1[i] -= transfer_ij
                        b_tplus1[j] += transfer_ij
        
        b_t_next_day = b_tplus1 / b_tplus1.sum()

        if is_debug_day:
            print("\n--- Analyse pour le rebalancement de DEMAIN ---")
            mu2_sorted = mu2.rename(permno_to_ticker).sort_values(ascending=False)
            print(f"Top 5 Gagnants (Perf. récente élevée):\n{mu2_sorted.head().to_string(float_format='{:.4f}'.format)}")
            print(f"\nTop 5 Perdants (Perf. récente faible):\n{mu2_sorted.tail().to_string(float_format='{:.4f}'.format)}")
            
            print("\n--- Top 5 des changements de pondération effectués ---")
            weight_changes = (b_t_next_day - b_t_rebalanced).rename(permno_to_ticker)
            top_changes = weight_changes.abs().nlargest(5)
            for ticker, change in top_changes.items():
                permno = next(key for key, val in permno_to_ticker.items() if val == ticker)
                old_weight = b_t_rebalanced[permno]
                new_weight = b_t_next_day[permno]
                print(f"  - {ticker:<6}: {old_weight:.2%} -> {new_weight:.2%} (Changement: {change:+.2%})")
            print(f"\nVérification de la somme des poids pour demain: {b_t_next_day.sum():.6f}")

        # Le portefeuille pour la prochaine itération est celui calculé pour t+1
        b_t = b_t_next_day

    results_df = pd.DataFrame(daily_returns_history, index=dates_history, columns=['daily_profit'])
    weights_df = pd.DataFrame(weights_history, index=dates_history)
    weights_df.columns = [f'weight_{permno_to_ticker.get(col, col)}' for col in weights_df.columns]
    
    return pd.concat([results_df, weights_df], axis=1)

# --- Exécutez le reste de votre code comme avant ---
# La seule chose à changer est l'appel de la fonction pour passer les arguments
print("\n🚀 Étape 5: Lancement du backtest de la stratégie Anticor(w=30)...")
resultats_strategie = run_anticor_strategy(final_matrix_relatives, w=30, permno_to_ticker=permno_to_ticker, debug_days=3) # debug_days=3 pour analyser les 3 premiers jours
resultats_strategie['profit_cumule'] = (1 + resultats_strategie['daily_profit']).cumprod()
print("\n✅ Backtest Anticor terminé !")

# ... le reste de votre code pour les benchmarks, graphiques et KPIs reste identique ...
# =============================================================================
# ÉTAPE 5: EXÉCUTION DU BACKTEST ANTICOR(w=30)
# =============================================================================
print("\n🚀 Étape 5: Lancement du backtest de la stratégie Anticor(w=30)...")
resultats_strategie = run_anticor_strategy(final_matrix_relatives, w=30, permno_to_ticker=permno_to_ticker)
resultats_strategie['profit_cumule'] = (1 + resultats_strategie['daily_profit']).cumprod()
print("\n✅ Backtest Anticor terminé !")

# =============================================================================
# ÉTAPE 6: CALCUL DES BENCHMARKS
# =============================================================================
print("\n🚀 Étape 6: Calcul des benchmarks (Meilleur Actif et Portefeuille Équipondéré)...")
df_prix_charges = 100 * final_matrix_relatives.cumprod()
df_prix_charges.rename(columns=permno_to_ticker, inplace=True)
best_performing_ticker = df_prix_charges.iloc[-1].idxmax()
start_date_strat = resultats_strategie.index[0]
best_asset_perf = (df_prix_charges[best_performing_ticker].loc[start_date_strat:] / df_prix_charges[best_performing_ticker].loc[start_date_strat])
ewp_daily_returns = final_matrix_relatives.mean(axis=1) - 1
ewp_perf = (1 + ewp_daily_returns.loc[start_date_strat:]).cumprod()
print(f"✅ Benchmarks calculés. Meilleur actif : {best_performing_ticker}")

# =============================================================================
# ÉTAPE 7: VISUALISATION ET KPIS
# =============================================================================
print("\n📊 Étape 7: Génération du graphique et des indicateurs de performance...")
fig, ax = plt.subplots(figsize=(16, 8))
resultats_strategie['profit_cumule'].plot(ax=ax, label='Stratégie Anticor (w=30)', lw=2.5, color='blue')
best_asset_perf.plot(ax=ax, label=f'Meilleur Actif (B&H): {best_performing_ticker}', linestyle='--', color='green')
ewp_perf.plot(ax=ax, label='Portefeuille Équipondéré (EWP)', linestyle=':', color='red')
ax.set_title('Comparaison de Performance : Anticor vs. Benchmarks')
ax.set_ylabel('Performance Cumulative (Échelle Log)')
ax.set_xlabel('Date')
ax.set_yscale('log')
ax.legend(loc='upper left')
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# --- Calcul et affichage des KPIs ---
def calculate_performance_metrics(daily_returns_series, risk_free_rate=0.0):
    trading_days_per_year = 252
    cumulative_return = (1 + daily_returns_series).prod() - 1
    num_days = len(daily_returns_series)
    annualized_return = (1 + cumulative_return) ** (trading_days_per_year / num_days) - 1
    annualized_volatility = daily_returns_series.std() * np.sqrt(trading_days_per_year)
    sharpe_ratio = (annualized_return - risk_free_rate) / annualized_volatility if annualized_volatility > 0 else 0
    cumulative_series = (1 + daily_returns_series).cumprod()
    peak = cumulative_series.expanding(min_periods=1).max()
    drawdown = (cumulative_series - peak) / peak
    max_drawdown = drawdown.min()
    calmar_ratio = annualized_return / abs(max_drawdown) if max_drawdown < 0 else 0
    return {
        "Rendement Cumulé": cumulative_return, "Rendement Annualisé": annualized_return,
        "Volatilité Annualisée": annualized_volatility, "Ratio de Sharpe": sharpe_ratio,
        "Max Drawdown": max_drawdown, "Ratio de Calmar": calmar_ratio
    }

metrics = {}
metrics['Anticor (w=30)'] = calculate_performance_metrics(resultats_strategie['daily_profit'])
metrics['EWP'] = calculate_performance_metrics(ewp_daily_returns.loc[start_date_strat:])
metrics[f'Meilleur Actif ({best_performing_ticker})'] = calculate_performance_metrics(best_asset_perf.pct_change().dropna())
results_table = pd.DataFrame(metrics).T
display(results_table.style.format({
    "Rendement Cumulé": "{:.2%}", "Rendement Annualisé": "{:.2%}",
    "Volatilité Annualisée": "{:.2%}", "Ratio de Sharpe": "{:.2f}",
    "Max Drawdown": "{:.2%}", "Ratio de Calmar": "{:.2f}"
}))
# Out:
# 🚀 Étape 1: Connexion à WRDS et définition des paramètres...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       7 # =============================================================================
#       8 # ÉTAPE 1: CONNEXION WRDS ET PARAMÈTRES
#       9 # =============================================================================
#      10 print("🚀 Étape 1: Connexion à WRDS et définition des paramètres...")
# ---> 11 db = wrds.Connection()
#      12 end_date = '2025-01-30'
#      13 trading_days = 1276
#
# File c:\Users\raphc\AppData\Local\Programs\Python\Python313\Lib\site-packages\wrds\sql.py:76, in Connection.__init__(self, autoconnect, verbose, **kwargs)
#      73 self._connect_args = kwargs.get("wrds_connect_args", WRDS_CONNECT_ARGS)
#      75 if autoconnect:
# ---> 76     self.connect()
#      77     self.load_library_list()
#
# File c:\Users\raphc\AppData\Local\Programs\Python\Python313\Lib\site-packages\wrds\sql.py:115, in Connection.connect(self)
#     111     self.__make_sa_engine_conn()
#     113 if self.engine is None:
#     114     # Use explicit username and password
# --> 115     self._username, self._password = self.__get_user_credentials()
#     116     # Last attempt, raise error if Exception encountered
#     117     self.__make_sa_engine_conn(raise_err=True)
#
# File c:\Users\raphc\AppData\Local\Programs\Python\Python313\Lib\site-packages\wrds\sql.py:216, in Connection.__get_user_credentials(self)
#     214 else:
#     215     uname = getpass.getuser()
# --> 216 username = input("Enter your WRDS username [{}]:".format(uname))
#     217 if not username:
#     218     username = uname
#
# File c:\Users\raphc\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File c:\Users\raphc\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# =============================================================================
# FONCTION POUR LA STRATÉGIE LISSÉE ANTI¹ (BAH(ANTICOR))
# =============================================================================

def run_anti1_strategy(price_relatives: pd.DataFrame, max_W: int, permno_to_ticker: dict):
    """
    Exécute la stratégie lissée ANTI¹ (BAH(ANTICOR)).
    Elle fait la moyenne des portefeuilles de ANTICOR(w) pour w allant de 2 à max_W.
    """
    print(f"🚀 Lancement du backtest pour ANTI¹ avec W_max={max_W}...")
    
    n = len(price_relatives)
    m = price_relatives.shape[1]
    asset_names = price_relatives.columns
    
    # Dictionnaire pour stocker les backtests de chaque "expert" ANTICOR(w)
    expert_portfolios = {}
    
    # Exécuter un backtest pour chaque w et stocker les poids quotidiens
    for w in range(2, max_W + 1):
        print(f"  - Calcul de l'expert ANTICOR(w={w})...")
        # Exécuter la stratégie pour un w donné
        temp_results = run_anticor_strategy(price_relatives, w, permno_to_ticker)
        # Extraire uniquement les poids
        expert_portfolios[w] = temp_results.filter(like='weight_')

    # Aligner tous les dataframes de poids sur un index commun (l'index complet)
    # et trouver la date de début commune (après la plus longue période de chauffe)
    start_date = price_relatives.index[2 * max_W]
    
    # Créer un panel de poids (Jours x Experts x Actifs)
    weights_panel = pd.Panel({w: df.loc[start_date:] for w, df in expert_portfolios.items() if not df.loc[start_date:].empty})
    
    # Calculer le portefeuille moyen chaque jour
    mean_weights_df = weights_panel.mean(axis=0)
    
    # Calculer les rendements quotidiens de la stratégie ANTI¹
    anti1_daily_returns = (mean_weights_df * (price_relatives.rename(columns=permno_to_ticker).loc[start_date:] - 1)).sum(axis=1)
    
    # Créer le DataFrame de résultats final
    results_df = pd.DataFrame(anti1_daily_returns, columns=['daily_profit'])
    results_df['profit_cumule'] = (1 + results_df['daily_profit']).cumprod()
    
    print("✅ Backtest ANTI¹ terminé !")
    return results_df


resultats_anti1 = run_anti1_strategy(final_matrix_relatives, max_W=30, permno_to_ticker=permno_to_ticker)


resultats_anti1['profit_cumule'].plot(ax=ax, label='Stratégie ANTI¹ (lissée)', lw=2.5, color='purple')
ax.legend()
plt.show()
# Out:
# 🚀 Lancement du backtest pour ANTI¹ avec W_max=30...
#   - Calcul de l'expert ANTICOR(w=2)...
#
# ==================== JOUR DE TRADING: 2019-12-11 (t=4) ====================
# Portefeuille initial pour aujourd'hui (b_t):
# permno
# 10104    0.0400
# 10107    0.0400
# 11850    0.0400
# 13407    0.0400
# 14542    0.0400
# 14593    0.0400
# 18163    0.0400
# 22111    0.0400
# 47896    0.0400
# 50876    0.0400
# 55976    0.0400
# 59408    0.0400
# 66181    0.0400
# 83443    0.0400
# 84788    0.0400
# 86580    0.0400
# 87055    0.0400
# 89393    0.0400
# 90215    0.0400
# 90319    0.0400
# 91233    0.0400
# 92611    0.0400
# 92655    0.0400
# 93002    0.0400
# 93436    0.0400
# dtype: object
#
# --- Analyse des transferts potentiels (Claims) ---
#   - Transfert envisagé: ORCL -> MSFT
#     - Perf. récente (μ₂): ORCL=0.0090 > MSFT=0.0011 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. MSFT (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> XOM
#     - Perf. récente (μ₂): ORCL=0.0090 > XOM=-0.0050 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. XOM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> FB
#     - Perf. récente (μ₂): ORCL=0.0090 > FB=0.0023 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. FB (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> AAPL
#     - Perf. récente (μ₂): ORCL=0.0090 > AAPL=0.0072 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. AAPL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> PG
#     - Perf. récente (μ₂): ORCL=0.0090 > PG=-0.0008 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: ORCL -> JNJ
#     - Perf. récente (μ₂): ORCL=0.0090 > JNJ=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JNJ (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> WMT
#     - Perf. récente (μ₂): ORCL=0.0090 > WMT=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. WMT (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> BAC
#     - Perf. récente (μ₂): ORCL=0.0090 > BAC=0.0019 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. BAC (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> BRK
#     - Perf. récente (μ₂): ORCL=0.0090 > BRK=0.0027 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. BRK (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> AMZN
#     - Perf. récente (μ₂): ORCL=0.0090 > AMZN=-0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. AMZN (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> NFLX
#     - Perf. récente (μ₂): ORCL=0.0090 > NFLX=-0.0059 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> CRM
#     - Perf. récente (μ₂): ORCL=0.0090 > CRM=-0.0035 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. CRM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> GOOGL
#     - Perf. récente (μ₂): ORCL=0.0090 > GOOGL=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> MA
#     - Perf. récente (μ₂): ORCL=0.0090 > MA=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. MA (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> V
#     - Perf. récente (μ₂): ORCL=0.0090 > V=-0.0025 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. V (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: ORCL -> AVGO
#     - Perf. récente (μ₂): ORCL=0.0090 > AVGO=0.0084 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. AVGO (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: MSFT -> GOOG
#     - Perf. récente (μ₂): MSFT=0.0011 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> JPM
#     - Perf. récente (μ₂): MSFT=0.0011 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> HD
#     - Perf. récente (μ₂): MSFT=0.0011 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: MSFT -> COST
#     - Perf. récente (μ₂): MSFT=0.0011 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: XOM -> HD
#     - Perf. récente (μ₂): XOM=-0.0050 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: FB -> GOOG
#     - Perf. récente (μ₂): FB=0.0023 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. FB (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: FB -> JPM
#     - Perf. récente (μ₂): FB=0.0023 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. FB (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: FB -> LLY
#     - Perf. récente (μ₂): FB=0.0023 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. FB (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: FB -> HD
#     - Perf. récente (μ₂): FB=0.0023 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. FB (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: FB -> COST
#     - Perf. récente (μ₂): FB=0.0023 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. FB (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: GOOG -> JPM
#     - Perf. récente (μ₂): GOOG=0.0005 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: GOOG -> HD
#     - Perf. récente (μ₂): GOOG=0.0005 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: GOOG -> COST
#     - Perf. récente (μ₂): GOOG=0.0005 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: AAPL -> GOOG
#     - Perf. récente (μ₂): AAPL=0.0072 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> JPM
#     - Perf. récente (μ₂): AAPL=0.0072 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> LLY
#     - Perf. récente (μ₂): AAPL=0.0072 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> HD
#     - Perf. récente (μ₂): AAPL=0.0072 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> COST
#     - Perf. récente (μ₂): AAPL=0.0072 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> UNH
#     - Perf. récente (μ₂): AAPL=0.0072 > UNH=0.0053 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. UNH (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: PG -> XOM
#     - Perf. récente (μ₂): PG=-0.0008 > XOM=-0.0050 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. XOM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: PG -> WMT
#     - Perf. récente (μ₂): PG=-0.0008 > WMT=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: PG -> NFLX
#     - Perf. récente (μ₂): PG=-0.0008 > NFLX=-0.0059 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: PG -> CRM
#     - Perf. récente (μ₂): PG=-0.0008 > CRM=-0.0035 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. CRM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: PG -> V
#     - Perf. récente (μ₂): PG=-0.0008 > V=-0.0025 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. V (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JNJ -> GOOG
#     - Perf. récente (μ₂): JNJ=0.0017 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JNJ -> JPM
#     - Perf. récente (μ₂): JNJ=0.0017 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JNJ -> HD
#     - Perf. récente (μ₂): JNJ=0.0017 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: JNJ -> COST
#     - Perf. récente (μ₂): JNJ=0.0017 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> HD
#     - Perf. récente (μ₂): JPM=-0.0009 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: LLY -> MSFT
#     - Perf. récente (μ₂): LLY=0.0022 > MSFT=0.0011 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. MSFT (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> XOM
#     - Perf. récente (μ₂): LLY=0.0022 > XOM=-0.0050 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. XOM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> PG
#     - Perf. récente (μ₂): LLY=0.0022 > PG=-0.0008 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: LLY -> JNJ
#     - Perf. récente (μ₂): LLY=0.0022 > JNJ=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JNJ (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> WMT
#     - Perf. récente (μ₂): LLY=0.0022 > WMT=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. WMT (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> BAC
#     - Perf. récente (μ₂): LLY=0.0022 > BAC=0.0019 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. BAC (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> AMZN
#     - Perf. récente (μ₂): LLY=0.0022 > AMZN=-0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. AMZN (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> NFLX
#     - Perf. récente (μ₂): LLY=0.0022 > NFLX=-0.0059 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> CRM
#     - Perf. récente (μ₂): LLY=0.0022 > CRM=-0.0035 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. CRM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> GOOGL
#     - Perf. récente (μ₂): LLY=0.0022 > GOOGL=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> MA
#     - Perf. récente (μ₂): LLY=0.0022 > MA=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. MA (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: LLY -> V
#     - Perf. récente (μ₂): LLY=0.0022 > V=-0.0025 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. V (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: WMT -> HD
#     - Perf. récente (μ₂): WMT=-0.0015 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. WMT (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: BAC -> GOOG
#     - Perf. récente (μ₂): BAC=0.0019 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BAC (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BAC -> JPM
#     - Perf. récente (μ₂): BAC=0.0019 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BAC (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BAC -> HD
#     - Perf. récente (μ₂): BAC=0.0019 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BAC (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: BAC -> COST
#     - Perf. récente (μ₂): BAC=0.0019 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BAC (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BRK -> GOOG
#     - Perf. récente (μ₂): BRK=0.0027 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BRK (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BRK -> JPM
#     - Perf. récente (μ₂): BRK=0.0027 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BRK (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BRK -> LLY
#     - Perf. récente (μ₂): BRK=0.0027 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BRK (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: BRK -> HD
#     - Perf. récente (μ₂): BRK=0.0027 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BRK (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: BRK -> COST
#     - Perf. récente (μ₂): BRK=0.0027 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BRK (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AMZN -> JPM
#     - Perf. récente (μ₂): AMZN=-0.0002 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AMZN (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AMZN -> HD
#     - Perf. récente (μ₂): AMZN=-0.0002 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AMZN (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: NVDA -> ORCL
#     - Perf. récente (μ₂): NVDA=0.0120 > ORCL=0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. ORCL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: NVDA -> GOOG
#     - Perf. récente (μ₂): NVDA=0.0120 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: NVDA -> JPM
#     - Perf. récente (μ₂): NVDA=0.0120 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: NVDA -> LLY
#     - Perf. récente (μ₂): NVDA=0.0120 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: NVDA -> HD
#     - Perf. récente (μ₂): NVDA=0.0120 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: NVDA -> COST
#     - Perf. récente (μ₂): NVDA=0.0120 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: NVDA -> UNH
#     - Perf. récente (μ₂): NVDA=0.0120 > UNH=0.0053 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NVDA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. UNH (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: COST -> JPM
#     - Perf. récente (μ₂): COST=0.0002 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. COST (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: COST -> HD
#     - Perf. récente (μ₂): COST=0.0002 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. COST (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: NFLX -> HD
#     - Perf. récente (μ₂): NFLX=-0.0059 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. NFLX (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: CRM -> HD
#     - Perf. récente (μ₂): CRM=-0.0035 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. CRM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: GOOGL -> JPM
#     - Perf. récente (μ₂): GOOGL=0.0005 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: GOOGL -> HD
#     - Perf. récente (μ₂): GOOGL=0.0005 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: GOOGL -> COST
#     - Perf. récente (μ₂): GOOGL=0.0005 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MA -> GOOG
#     - Perf. récente (μ₂): MA=0.0017 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MA -> JPM
#     - Perf. récente (μ₂): MA=0.0017 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MA -> HD
#     - Perf. récente (μ₂): MA=0.0017 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: MA -> COST
#     - Perf. récente (μ₂): MA=0.0017 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: V -> XOM
#     - Perf. récente (μ₂): V=-0.0025 > XOM=-0.0050 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. XOM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: V -> NFLX
#     - Perf. récente (μ₂): V=-0.0025 > NFLX=-0.0059 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: V -> CRM
#     - Perf. récente (μ₂): V=-0.0025 > CRM=-0.0035 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. CRM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: UNH -> GOOG
#     - Perf. récente (μ₂): UNH=0.0053 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: UNH -> JPM
#     - Perf. récente (μ₂): UNH=0.0053 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: UNH -> LLY
#     - Perf. récente (μ₂): UNH=0.0053 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: UNH -> HD
#     - Perf. récente (μ₂): UNH=0.0053 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: UNH -> COST
#     - Perf. récente (μ₂): UNH=0.0053 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: AVGO -> GOOG
#     - Perf. récente (μ₂): AVGO=0.0084 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AVGO -> JPM
#     - Perf. récente (μ₂): AVGO=0.0084 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AVGO -> LLY
#     - Perf. récente (μ₂): AVGO=0.0084 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AVGO -> HD
#     - Perf. récente (μ₂): AVGO=0.0084 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AVGO -> COST
#     - Perf. récente (μ₂): AVGO=0.0084 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AVGO -> UNH
#     - Perf. récente (μ₂): AVGO=0.0084 > UNH=0.0053 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. UNH (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: TSLA -> ORCL
#     - Perf. récente (μ₂): TSLA=0.0190 > ORCL=0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. ORCL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: TSLA -> GOOG
#     - Perf. récente (μ₂): TSLA=0.0190 > GOOG=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: TSLA -> JPM
#     - Perf. récente (μ₂): TSLA=0.0190 > JPM=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. JPM (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: TSLA -> LLY
#     - Perf. récente (μ₂): TSLA=0.0190 > LLY=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: TSLA -> HD
#     - Perf. récente (μ₂): TSLA=0.0190 > HD=-0.0106 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: TSLA -> COST
#     - Perf. récente (μ₂): TSLA=0.0190 > COST=0.0002 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: TSLA -> UNH
#     - Perf. récente (μ₂): TSLA=0.0190 > UNH=0.0053 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
# -> Total de 108 paires d'actifs avec un 'claim' > 0.
#
# --- Mise à jour du portefeuille pour demain ---
# Vérification de la somme des poids (b_t+1): 1.000000
#
# ==================== JOUR DE TRADING: 2019-12-12 (t=5) ====================
# Portefeuille initial pour aujourd'hui (b_t):
# permno
# 10104     0.0152
# 10107     0.0061
# 11850     0.0283
# 13407     0.0026
# 14542     0.0750
# 14593     0.0026
# 18163     0.0041
# 22111     0.0061
# 47896     0.1256
# 50876     0.0639
# 55976     0.0150
# 59408     0.0061
# 66181     0.4438
# 83443     0.0026
# 84788     0.0061
# 86580    -0.0000
# 87055     0.0963
# 89393     0.0283
# 90215     0.0283
# 90319     0.0061
# 91233     0.0061
# 92611     0.0085
# 92655     0.0203
# 93002     0.0026
# 93436    -0.0000
# dtype: object
#
# --- Analyse des transferts potentiels (Claims) ---
#   - Transfert envisagé: ORCL -> GOOG
#     - Perf. récente (μ₂): ORCL=0.0058 > GOOG=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> LLY
#     - Perf. récente (μ₂): ORCL=0.0058 > LLY=0.0043 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> WMT
#     - Perf. récente (μ₂): ORCL=0.0058 > WMT=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. WMT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: ORCL -> HD
#     - Perf. récente (μ₂): ORCL=0.0058 > HD=-0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> COST
#     - Perf. récente (μ₂): ORCL=0.0058 > COST=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: ORCL -> GOOGL
#     - Perf. récente (μ₂): ORCL=0.0058 > GOOGL=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: ORCL -> V
#     - Perf. récente (μ₂): ORCL=0.0058 > V=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. ORCL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. V (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: MSFT -> GOOG
#     - Perf. récente (μ₂): MSFT=0.0069 > GOOG=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> LLY
#     - Perf. récente (μ₂): MSFT=0.0069 > LLY=0.0043 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> WMT
#     - Perf. récente (μ₂): MSFT=0.0069 > WMT=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: MSFT -> HD
#     - Perf. récente (μ₂): MSFT=0.0069 > HD=-0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> AMZN
#     - Perf. récente (μ₂): MSFT=0.0069 > AMZN=0.0060 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. AMZN (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> COST
#     - Perf. récente (μ₂): MSFT=0.0069 > COST=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: MSFT -> GOOGL
#     - Perf. récente (μ₂): MSFT=0.0069 > GOOGL=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: MSFT -> MA
#     - Perf. récente (μ₂): MSFT=0.0069 > MA=0.0062 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. MA (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: MSFT -> V
#     - Perf. récente (μ₂): MSFT=0.0069 > V=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. MSFT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. V (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: XOM -> ORCL
#     - Perf. récente (μ₂): XOM=0.0092 > ORCL=0.0058 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. ORCL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: XOM -> FB
#     - Perf. récente (μ₂): XOM=0.0092 > FB=-0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. FB (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: XOM -> AAPL
#     - Perf. récente (μ₂): XOM=0.0092 > AAPL=0.0055 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. AAPL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: XOM -> PG
#     - Perf. récente (μ₂): XOM=0.0092 > PG=0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: XOM -> JNJ
#     - Perf. récente (μ₂): XOM=0.0092 > JNJ=0.0048 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. JNJ (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: XOM -> NFLX
#     - Perf. récente (μ₂): XOM=0.0092 > NFLX=0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. XOM (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. NFLX (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: GOOG -> FB
#     - Perf. récente (μ₂): GOOG=0.0021 > FB=-0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOG (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. FB (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: GOOG -> PG
#     - Perf. récente (μ₂): GOOG=0.0021 > PG=0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. GOOG (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> GOOG
#     - Perf. récente (μ₂): AAPL=0.0055 > GOOG=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> LLY
#     - Perf. récente (μ₂): AAPL=0.0055 > LLY=0.0043 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> WMT
#     - Perf. récente (μ₂): AAPL=0.0055 > WMT=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. WMT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> HD
#     - Perf. récente (μ₂): AAPL=0.0055 > HD=-0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> COST
#     - Perf. récente (μ₂): AAPL=0.0055 > COST=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: AAPL -> GOOGL
#     - Perf. récente (μ₂): AAPL=0.0055 > GOOGL=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: AAPL -> V
#     - Perf. récente (μ₂): AAPL=0.0055 > V=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. AAPL (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. V (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 3.0000
#   - Transfert envisagé: PG -> FB
#     - Perf. récente (μ₂): PG=0.0012 > FB=-0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. PG (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. FB (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JNJ -> FB
#     - Perf. récente (μ₂): JNJ=0.0048 > FB=-0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. FB (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JNJ -> PG
#     - Perf. récente (μ₂): JNJ=0.0048 > PG=0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JNJ (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> MSFT
#     - Perf. récente (μ₂): JPM=0.0129 > MSFT=0.0069 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. MSFT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> XOM
#     - Perf. récente (μ₂): JPM=0.0129 > XOM=0.0092 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. XOM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> GOOG
#     - Perf. récente (μ₂): JPM=0.0129 > GOOG=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> LLY
#     - Perf. récente (μ₂): JPM=0.0129 > LLY=0.0043 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> WMT
#     - Perf. récente (μ₂): JPM=0.0129 > WMT=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> HD
#     - Perf. récente (μ₂): JPM=0.0129 > HD=-0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> BRK
#     - Perf. récente (μ₂): JPM=0.0129 > BRK=0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. BRK (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> AMZN
#     - Perf. récente (μ₂): JPM=0.0129 > AMZN=0.0060 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. AMZN (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> COST
#     - Perf. récente (μ₂): JPM=0.0129 > COST=0.0026 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. COST (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> CRM
#     - Perf. récente (μ₂): JPM=0.0129 > CRM=0.0070 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. CRM (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> GOOGL
#     - Perf. récente (μ₂): JPM=0.0129 > GOOGL=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> MA
#     - Perf. récente (μ₂): JPM=0.0129 > MA=0.0062 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. MA (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: JPM -> V
#     - Perf. récente (μ₂): JPM=0.0129 > V=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. V (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: JPM -> UNH
#     - Perf. récente (μ₂): JPM=0.0129 > UNH=0.0073 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. JPM (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: LLY -> FB
#     - Perf. récente (μ₂): LLY=0.0043 > FB=-0.0104 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. FB (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: LLY -> PG
#     - Perf. récente (μ₂): LLY=0.0043 > PG=0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. LLY (M_cor(i,i)): -1.0000 -> Bonus: 1.0000
#     - Auto-corr. PG (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: WMT -> GOOG
#     - Perf. récente (μ₂): WMT=0.0026 > GOOG=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. WMT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: WMT -> HD
#     - Perf. récente (μ₂): WMT=0.0026 > HD=-0.0090 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. WMT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: WMT -> GOOGL
#     - Perf. récente (μ₂): WMT=0.0026 > GOOGL=0.0021 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. WMT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: WMT -> V
#     - Perf. récente (μ₂): WMT=0.0026 > V=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. WMT (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. V (M_cor(j,j)): -1.0000 -> Bonus: 1.0000
#     - Claim final: 2.0000
#   - Transfert envisagé: BAC -> MSFT
#     - Perf. récente (μ₂): BAC=0.0169 > MSFT=0.0069 (OK)
#     - Corr. croisée M_cor(i,j): 1.0000 (OK > 0)
#     - Auto-corr. BAC (M_cor(i,i)): 1.0000 -> Bonus: 0.0000
#     - Auto-corr. MSFT (M_cor(j,j)): 1.0000 -> Bonus: 0.0000
#     - Claim final: 1.0000
#   - Transfert envisagé: BAC -> XOM
# ...
#     - Claim final: 0.8159
#   - Transfert envisagé: GOOGL -> WMT
#     - Perf. récente (μ₂): GOOGL=0.0011 > WMT=-0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 0.2799 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): 0.0578 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 0.4831 -> Bonus: 0.0000
#     - Claim final: 0.2799
#   - Transfert envisagé: GOOGL -> HD
#     - Perf. récente (μ₂): GOOGL=0.0011 > HD=-0.0003 (OK)
#     - Corr. croisée M_cor(i,j): 0.1566 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): 0.0578 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): 0.1659 -> Bonus: 0.0000
#     - Claim final: 0.1566
#   - Transfert envisagé: GOOGL -> NFLX
#     - Perf. récente (μ₂): GOOGL=0.0011 > NFLX=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.0717 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): 0.0578 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -0.3787 -> Bonus: 0.3787
#     - Claim final: 0.4504
#   - Transfert envisagé: GOOGL -> UNH
#     - Perf. récente (μ₂): GOOGL=0.0011 > UNH=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.1857 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): 0.0578 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 0.2530 -> Bonus: 0.0000
#     - Claim final: 0.1857
#   - Transfert envisagé: GOOGL -> AVGO
#     - Perf. récente (μ₂): GOOGL=0.0011 > AVGO=0.0006 (OK)
#     - Corr. croisée M_cor(i,j): 0.1914 (OK > 0)
#     - Auto-corr. GOOGL (M_cor(i,i)): 0.0578 -> Bonus: 0.0000
#     - Auto-corr. AVGO (M_cor(j,j)): 0.0895 -> Bonus: 0.0000
#     - Claim final: 0.1914
#   - Transfert envisagé: MA -> ORCL
#     - Perf. récente (μ₂): MA=0.0024 > ORCL=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 0.3242 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. ORCL (M_cor(j,j)): 0.3432 -> Bonus: 0.0000
#     - Claim final: 0.3242
#   - Transfert envisagé: MA -> FB
#     - Perf. récente (μ₂): MA=0.0024 > FB=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 0.6034 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. FB (M_cor(j,j)): 0.2559 -> Bonus: 0.0000
#     - Claim final: 0.6034
#   - Transfert envisagé: MA -> GOOG
#     - Perf. récente (μ₂): MA=0.0024 > GOOG=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 0.6889 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -0.0164 -> Bonus: 0.0164
#     - Claim final: 0.7054
#   - Transfert envisagé: MA -> WMT
#     - Perf. récente (μ₂): MA=0.0024 > WMT=-0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 0.2252 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 0.4831 -> Bonus: 0.0000
#     - Claim final: 0.2252
#   - Transfert envisagé: MA -> HD
#     - Perf. récente (μ₂): MA=0.0024 > HD=-0.0003 (OK)
#     - Corr. croisée M_cor(i,j): 0.2448 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): 0.1659 -> Bonus: 0.0000
#     - Claim final: 0.2448
#   - Transfert envisagé: MA -> BRK
#     - Perf. récente (μ₂): MA=0.0024 > BRK=0.0018 (OK)
#     - Corr. croisée M_cor(i,j): 0.2570 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. BRK (M_cor(j,j)): -0.4853 -> Bonus: 0.4853
#     - Claim final: 0.7423
#   - Transfert envisagé: MA -> NVDA
#     - Perf. récente (μ₂): MA=0.0024 > NVDA=0.0023 (OK)
#     - Corr. croisée M_cor(i,j): 0.1412 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. NVDA (M_cor(j,j)): 0.0799 -> Bonus: 0.0000
#     - Claim final: 0.1412
#   - Transfert envisagé: MA -> NFLX
#     - Perf. récente (μ₂): MA=0.0024 > NFLX=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.2339 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -0.3787 -> Bonus: 0.3787
#     - Claim final: 0.6126
#   - Transfert envisagé: MA -> GOOGL
#     - Perf. récente (μ₂): MA=0.0024 > GOOGL=0.0011 (OK)
#     - Corr. croisée M_cor(i,j): 0.7022 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): 0.0578 -> Bonus: 0.0000
#     - Claim final: 0.7022
#   - Transfert envisagé: MA -> UNH
#     - Perf. récente (μ₂): MA=0.0024 > UNH=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.3808 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 0.2530 -> Bonus: 0.0000
#     - Claim final: 0.3808
#   - Transfert envisagé: MA -> AVGO
#     - Perf. récente (μ₂): MA=0.0024 > AVGO=0.0006 (OK)
#     - Corr. croisée M_cor(i,j): 0.2052 (OK > 0)
#     - Auto-corr. MA (M_cor(i,i)): 0.5023 -> Bonus: 0.0000
#     - Auto-corr. AVGO (M_cor(j,j)): 0.0895 -> Bonus: 0.0000
#     - Claim final: 0.2052
#   - Transfert envisagé: V -> ORCL
#     - Perf. récente (μ₂): V=0.0030 > ORCL=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 0.3257 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. ORCL (M_cor(j,j)): 0.3432 -> Bonus: 0.0000
#     - Claim final: 0.3257
#   - Transfert envisagé: V -> XOM
#     - Perf. récente (μ₂): V=0.0030 > XOM=0.0027 (OK)
#     - Corr. croisée M_cor(i,j): 0.1461 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. XOM (M_cor(j,j)): -0.4753 -> Bonus: 0.4753
#     - Claim final: 0.6214
#   - Transfert envisagé: V -> FB
#     - Perf. récente (μ₂): V=0.0030 > FB=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 0.6783 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. FB (M_cor(j,j)): 0.2559 -> Bonus: 0.0000
#     - Claim final: 0.6783
#   - Transfert envisagé: V -> GOOG
#     - Perf. récente (μ₂): V=0.0030 > GOOG=0.0010 (OK)
#     - Corr. croisée M_cor(i,j): 0.6982 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. GOOG (M_cor(j,j)): -0.0164 -> Bonus: 0.0164
#     - Claim final: 0.7147
#   - Transfert envisagé: V -> PG
#     - Perf. récente (μ₂): V=0.0030 > PG=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 0.0133 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. PG (M_cor(j,j)): -0.3938 -> Bonus: 0.3938
#     - Claim final: 0.4071
#   - Transfert envisagé: V -> LLY
#     - Perf. récente (μ₂): V=0.0030 > LLY=0.0013 (OK)
#     - Corr. croisée M_cor(i,j): 0.0670 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): 0.0222 -> Bonus: 0.0000
#     - Claim final: 0.0670
#   - Transfert envisagé: V -> WMT
#     - Perf. récente (μ₂): V=0.0030 > WMT=-0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 0.3793 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 0.4831 -> Bonus: 0.0000
#     - Claim final: 0.3793
#   - Transfert envisagé: V -> BAC
#     - Perf. récente (μ₂): V=0.0030 > BAC=0.0024 (OK)
#     - Corr. croisée M_cor(i,j): 0.5491 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. BAC (M_cor(j,j)): -0.4839 -> Bonus: 0.4839
#     - Claim final: 1.0330
#   - Transfert envisagé: V -> HD
#     - Perf. récente (μ₂): V=0.0030 > HD=-0.0003 (OK)
#     - Corr. croisée M_cor(i,j): 0.2836 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): 0.1659 -> Bonus: 0.0000
#     - Claim final: 0.2836
#   - Transfert envisagé: V -> BRK
#     - Perf. récente (μ₂): V=0.0030 > BRK=0.0018 (OK)
#     - Corr. croisée M_cor(i,j): 0.3880 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. BRK (M_cor(j,j)): -0.4853 -> Bonus: 0.4853
#     - Claim final: 0.8733
#   - Transfert envisagé: V -> NVDA
#     - Perf. récente (μ₂): V=0.0030 > NVDA=0.0023 (OK)
#     - Corr. croisée M_cor(i,j): 0.1193 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. NVDA (M_cor(j,j)): 0.0799 -> Bonus: 0.0000
#     - Claim final: 0.1193
#   - Transfert envisagé: V -> NFLX
#     - Perf. récente (μ₂): V=0.0030 > NFLX=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.2269 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -0.3787 -> Bonus: 0.3787
#     - Claim final: 0.6056
#   - Transfert envisagé: V -> CRM
#     - Perf. récente (μ₂): V=0.0030 > CRM=0.0028 (OK)
#     - Corr. croisée M_cor(i,j): 0.5821 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. CRM (M_cor(j,j)): 0.3854 -> Bonus: 0.0000
#     - Claim final: 0.5821
#   - Transfert envisagé: V -> GOOGL
#     - Perf. récente (μ₂): V=0.0030 > GOOGL=0.0011 (OK)
#     - Corr. croisée M_cor(i,j): 0.7157 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. GOOGL (M_cor(j,j)): 0.0578 -> Bonus: 0.0000
#     - Claim final: 0.7157
#   - Transfert envisagé: V -> MA
#     - Perf. récente (μ₂): V=0.0030 > MA=0.0024 (OK)
#     - Corr. croisée M_cor(i,j): 0.6452 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. MA (M_cor(j,j)): 0.5023 -> Bonus: 0.0000
#     - Claim final: 0.6452
#   - Transfert envisagé: V -> UNH
#     - Perf. récente (μ₂): V=0.0030 > UNH=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.2534 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 0.2530 -> Bonus: 0.0000
#     - Claim final: 0.2534
#   - Transfert envisagé: V -> AVGO
#     - Perf. récente (μ₂): V=0.0030 > AVGO=0.0006 (OK)
#     - Corr. croisée M_cor(i,j): 0.1524 (OK > 0)
#     - Auto-corr. V (M_cor(i,i)): 0.6268 -> Bonus: 0.0000
#     - Auto-corr. AVGO (M_cor(j,j)): 0.0895 -> Bonus: 0.0000
#     - Claim final: 0.1524
#   - Transfert envisagé: UNH -> PG
#     - Perf. récente (μ₂): UNH=-0.0009 > PG=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 0.7776 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 0.2530 -> Bonus: 0.0000
#     - Auto-corr. PG (M_cor(j,j)): -0.3938 -> Bonus: 0.3938
#     - Claim final: 1.1714
#   - Transfert envisagé: UNH -> WMT
#     - Perf. récente (μ₂): UNH=-0.0009 > WMT=-0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 0.3185 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 0.2530 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 0.4831 -> Bonus: 0.0000
#     - Claim final: 0.3185
#   - Transfert envisagé: UNH -> NFLX
#     - Perf. récente (μ₂): UNH=-0.0009 > NFLX=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.1112 (OK > 0)
#     - Auto-corr. UNH (M_cor(i,i)): 0.2530 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -0.3787 -> Bonus: 0.3787
#     - Claim final: 0.4899
#   - Transfert envisagé: AVGO -> PG
#     - Perf. récente (μ₂): AVGO=0.0006 > PG=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 0.3389 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): 0.0895 -> Bonus: 0.0000
#     - Auto-corr. PG (M_cor(j,j)): -0.3938 -> Bonus: 0.3938
#     - Claim final: 0.7326
#   - Transfert envisagé: AVGO -> UNH
#     - Perf. récente (μ₂): AVGO=0.0006 > UNH=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.0175 (OK > 0)
#     - Auto-corr. AVGO (M_cor(i,i)): 0.0895 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 0.2530 -> Bonus: 0.0000
#     - Claim final: 0.0175
#   - Transfert envisagé: TSLA -> ORCL
#     - Perf. récente (μ₂): TSLA=0.0079 > ORCL=0.0017 (OK)
#     - Corr. croisée M_cor(i,j): 0.3142 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. ORCL (M_cor(j,j)): 0.3432 -> Bonus: 0.0000
#     - Claim final: 0.3142
#   - Transfert envisagé: TSLA -> MSFT
#     - Perf. récente (μ₂): TSLA=0.0079 > MSFT=0.0039 (OK)
#     - Corr. croisée M_cor(i,j): 0.2188 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. MSFT (M_cor(j,j)): 0.4609 -> Bonus: 0.0000
#     - Claim final: 0.2188
#   - Transfert envisagé: TSLA -> XOM
#     - Perf. récente (μ₂): TSLA=0.0079 > XOM=0.0027 (OK)
#     - Corr. croisée M_cor(i,j): 0.1211 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. XOM (M_cor(j,j)): -0.4753 -> Bonus: 0.4753
#     - Claim final: 0.5964
#   - Transfert envisagé: TSLA -> FB
#     - Perf. récente (μ₂): TSLA=0.0079 > FB=0.0022 (OK)
#     - Corr. croisée M_cor(i,j): 0.2420 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. FB (M_cor(j,j)): 0.2559 -> Bonus: 0.0000
#     - Claim final: 0.2420
#   - Transfert envisagé: TSLA -> PG
#     - Perf. récente (μ₂): TSLA=0.0079 > PG=-0.0015 (OK)
#     - Corr. croisée M_cor(i,j): 0.5902 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. PG (M_cor(j,j)): -0.3938 -> Bonus: 0.3938
#     - Claim final: 0.9839
#   - Transfert envisagé: TSLA -> JNJ
#     - Perf. récente (μ₂): TSLA=0.0079 > JNJ=0.0005 (OK)
#     - Corr. croisée M_cor(i,j): 0.3113 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. JNJ (M_cor(j,j)): -0.4557 -> Bonus: 0.4557
#     - Claim final: 0.7669
#   - Transfert envisagé: TSLA -> JPM
#     - Perf. récente (μ₂): TSLA=0.0079 > JPM=0.0034 (OK)
#     - Corr. croisée M_cor(i,j): 0.0100 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. JPM (M_cor(j,j)): -0.3894 -> Bonus: 0.3894
#     - Claim final: 0.3994
#   - Transfert envisagé: TSLA -> LLY
#     - Perf. récente (μ₂): TSLA=0.0079 > LLY=0.0013 (OK)
#     - Corr. croisée M_cor(i,j): 0.3847 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. LLY (M_cor(j,j)): 0.0222 -> Bonus: 0.0000
#     - Claim final: 0.3847
#   - Transfert envisagé: TSLA -> WMT
#     - Perf. récente (μ₂): TSLA=0.0079 > WMT=-0.0012 (OK)
#     - Corr. croisée M_cor(i,j): 0.1616 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. WMT (M_cor(j,j)): 0.4831 -> Bonus: 0.0000
#     - Claim final: 0.1616
#   - Transfert envisagé: TSLA -> HD
#     - Perf. récente (μ₂): TSLA=0.0079 > HD=-0.0003 (OK)
#     - Corr. croisée M_cor(i,j): 0.3377 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. HD (M_cor(j,j)): 0.1659 -> Bonus: 0.0000
#     - Claim final: 0.3377
#   - Transfert envisagé: TSLA -> BRK
#     - Perf. récente (μ₂): TSLA=0.0079 > BRK=0.0018 (OK)
#     - Corr. croisée M_cor(i,j): 0.0668 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. BRK (M_cor(j,j)): -0.4853 -> Bonus: 0.4853
#     - Claim final: 0.5521
#   - Transfert envisagé: TSLA -> NVDA
#     - Perf. récente (μ₂): TSLA=0.0079 > NVDA=0.0023 (OK)
#     - Corr. croisée M_cor(i,j): 0.2411 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. NVDA (M_cor(j,j)): 0.0799 -> Bonus: 0.0000
#     - Claim final: 0.2411
#   - Transfert envisagé: TSLA -> NFLX
#     - Perf. récente (μ₂): TSLA=0.0079 > NFLX=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.2142 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. NFLX (M_cor(j,j)): -0.3787 -> Bonus: 0.3787
#     - Claim final: 0.5929
#   - Transfert envisagé: TSLA -> CRM
#     - Perf. récente (μ₂): TSLA=0.0079 > CRM=0.0028 (OK)
#     - Corr. croisée M_cor(i,j): 0.3287 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. CRM (M_cor(j,j)): 0.3854 -> Bonus: 0.0000
#     - Claim final: 0.3287
#   - Transfert envisagé: TSLA -> MA
#     - Perf. récente (μ₂): TSLA=0.0079 > MA=0.0024 (OK)
#     - Corr. croisée M_cor(i,j): 0.4558 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. MA (M_cor(j,j)): 0.5023 -> Bonus: 0.0000
#     - Claim final: 0.4558
#   - Transfert envisagé: TSLA -> V
#     - Perf. récente (μ₂): TSLA=0.0079 > V=0.0030 (OK)
#     - Corr. croisée M_cor(i,j): 0.2065 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. V (M_cor(j,j)): 0.6268 -> Bonus: 0.0000
#     - Claim final: 0.2065
#   - Transfert envisagé: TSLA -> UNH
#     - Perf. récente (μ₂): TSLA=0.0079 > UNH=-0.0009 (OK)
#     - Corr. croisée M_cor(i,j): 0.0081 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. UNH (M_cor(j,j)): 0.2530 -> Bonus: 0.0000
#     - Claim final: 0.0081
#   - Transfert envisagé: TSLA -> AVGO
#     - Perf. récente (μ₂): TSLA=0.0079 > AVGO=0.0006 (OK)
#     - Corr. croisée M_cor(i,j): 0.3021 (OK > 0)
#     - Auto-corr. TSLA (M_cor(i,i)): 0.1732 -> Bonus: 0.0000
#     - Auto-corr. AVGO (M_cor(j,j)): 0.0895 -> Bonus: 0.0000
#     - Claim final: 0.3021
# -> Total de 153 paires d'actifs avec un 'claim' > 0.
#
# --- Mise à jour du portefeuille pour demain ---
# Vérification de la somme des poids (b_t+1): 1.000000
